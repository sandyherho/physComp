# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df = pd.read_csv('part3example.csv')

# %%
df.head()
# Out:
#          Date          y         X
# 0  2020-01-01   9.202897  4.580200
# 1  2020-01-02  10.918828  5.813925
# 2  2020-01-03  11.895763  5.791927
# 3  2020-01-04  11.579845  5.176845
# 4  2020-01-05   8.572679  4.019310

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    213 non-null    object
#  1   y       213 non-null    float64
#  2   X       213 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 5.1+ KB

# %%
df = pd.read_csv('part3example.csv', parse_dates=['Date'], index_col='Date')

# %%
df.head()
# Out:
#                     y         X
# Date
# 2020-01-01   9.202897  4.580200
# 2020-01-02  10.918828  5.813925
# 2020-01-03  11.895763  5.791927
# 2020-01-04  11.579845  5.176845
# 2020-01-05   8.572679  4.019310

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 213 entries, 2020-01-01 to 2020-07-31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       213 non-null    float64
#  1   X       213 non-null    float64
# dtypes: float64(2)
# memory usage: 5.0 KB

# %%
df.plot(figsize=(15,6));

# %%
df = pd.read_csv('part3example.csv')

# %%
df.head()
# Out:
#          Date          y         X
# 0  2020-01-01   9.202897  4.580200
# 1  2020-01-02  10.918828  5.813925
# 2  2020-01-03  11.895763  5.791927
# 3  2020-01-04  11.579845  5.176845
# 4  2020-01-05   8.572679  4.019310

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#                     y         X
# Date
# 2020-01-01   9.202897  4.580200
# 2020-01-02  10.918828  5.813925
# 2020-01-03  11.895763  5.791927
# 2020-01-04  11.579845  5.176845
# 2020-01-05   8.572679  4.019310
